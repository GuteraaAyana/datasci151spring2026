# %% [markdown]
# <span style="color:cyan"> <font size = "1000"> This is my first Jupyter notebook </span>

# %%
print("My name is Guteraa Zelalem Ayana the only")
# Out:
# My name is Guteraa Zelalem Ayana the only

# %%
print("daniyal khan")
# Out:
# daniyal khan
